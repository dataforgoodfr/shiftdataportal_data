# %%
import pandas as pd
import numpy as np
import hvplot.pandas  # noqa
import os
import sys
import re
pd.options.plotting.backend = 'holoviews'

# %% [markdown]
# ## Utils

# %%
# Function to replace a substring in a string column
def process_values(value):
    if isinstance(value, str):
        value = re.sub(r'[\r\n]+', ' - ', value).strip('"\' \)\()')

    return np.nan if not value else value


# Clean columns content
def process_columns(column_name):
    # return column_name

    # BASIC
    column_name = re.sub(r'([A-Z]+)', r' \1', column_name.lower())
    column_name = re.sub(r'(\s+|\.)', r' ', column_name).strip()
    column_name = re.sub(r'(\s+)', r'_', column_name)
    
    return column_name

# FORMAT DF:
def process_df(df):
    # PROCESSING
    # STRING VALUES (might set to NaN)
    df = df.applymap(process_values)
    # Uniformize NaN values
    df = df.replace(['', 'nan'], np.nan)

    # Drop all columns having only NaN
    df = df.dropna(axis=1, how='all')

    # Replace column names using the format function
    df = df.rename(columns=process_columns)

    # Filter value if exists
    if ('value' in df.columns):
        df = df.dropna(subset=['value'])
    
    # Change year type to int
    if ('year' in df.columns):
        df['year'] = df['year'].astype(int)   

    return df

def func(x):
    if x['ember_region'] == 'Middle East':
        return 1.
    else:
        return np.nan

def lfunc(x):
    res = ''
    if x['eu'] == 1.:
        res += 'eu,'
    if x['oecd'] == 1.:
        res += 'oecd,'
    if x['g20'] == 1.:
        res += 'g20,'
    if x['g7'] == 1.:
        res += 'g7,'
    if x['middle_east'] == 1.:
        res += 'middle_east,'  
    if res == '':
        return np.nan
    
    return res[:-1]

# %% [markdown]
# ## Load and Process Data

# %%
df_ember = pd.read_csv("../../../data/_raw/ember/ember_file_elec_all_year.csv")
df_ember = process_df(df_ember)
df_ember.head()
# Out:
#           area country_code  year area_type continent ember_region  eu  oecd  \
# 0  Afghanistan          AFG  2000   Country      Asia         Asia NaN   NaN
# 1  Afghanistan          AFG  2000   Country      Asia         Asia NaN   NaN
# 2  Afghanistan          AFG  2000   Country      Asia         Asia NaN   NaN
# 3  Afghanistan          AFG  2000   Country      Asia         Asia NaN   NaN
# 4  Afghanistan          AFG  2000   Country      Asia         Asia NaN   NaN
#
#    g20  g7  category     subcategory                               variable  \
# 0  NaN NaN  Capacity  Aggregate fuel                                  Clean
# 1  NaN NaN  Capacity  Aggregate fuel                                 Fossil
# 2  NaN NaN  Capacity  Aggregate fuel                   Gas and Other Fossil
# 3  NaN NaN  Capacity  Aggregate fuel  Hydro, Bioenergy and Other Renewables
# 4  NaN NaN  Capacity  Aggregate fuel                             Renewables
#
#   unit  value  yoy_absolute_change  yoy_%_change
# 0   GW   0.19                  NaN           NaN
# 1   GW   0.03                  NaN           NaN
# 2   GW   0.03                  NaN           NaN
# 3   GW   0.19                  NaN           NaN
# 4   GW   0.19                  NaN           NaN

# %%
df_info = pd.read_csv("../../../data/_info/__INFO_UN_M49_en.csv")
df_info = process_df(df_info)
df_info.head()
# Out:
#    global_code global_name  region_code region_name  sub-region_code  \
# 0            1       World          2.0      Africa             15.0
# 1            1       World          2.0      Africa             15.0
# 2            1       World          2.0      Africa             15.0
# 3            1       World          2.0      Africa             15.0
# 4            1       World          2.0      Africa             15.0
#
#    sub-region_name  intermediate_region_code intermediate_region_name  \
# 0  Northern Africa                       NaN                      NaN
# 1  Northern Africa                       NaN                      NaN
# 2  Northern Africa                       NaN                      NaN
# 3  Northern Africa                       NaN                      NaN
# 4  Northern Africa                       NaN                      NaN
#
#   country_or_area  m49_code iso-alpha2_code iso-alpha3_code  \
# 0         Algeria        12              DZ             DZA
# 1           Egypt       818              EG             EGY
# 2           Libya       434              LY             LBY
# 3         Morocco       504              MA             MAR
# 4           Sudan       729              SD             SDN
#
#   least_developed_countries_(ldc) land_locked_developing_countries_(lldc)  \
# 0                             NaN                                     NaN
# 1                             NaN                                     NaN
# 2                             NaN                                     NaN
# 3                             NaN                                     NaN
# 4                               x                                     NaN
#
#   small_island_developing_states_(sids)
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN

# %%
# Left joining
df_ember = df_ember.merge(df_info, left_on='country_code', right_on='iso-alpha3_code', how='left')

# %%
# Filter columns
selected_columns = ['area', 'country_code', 'year', 'area_type', 'region_name', 'ember_region', 'sub-region_name', 'eu', 'oecd', 'g20', 'g7', 'category', 'subcategory', 'variable', 'unit', 'value']
df_ember = df_ember[selected_columns]

# Create new column "middle_east"
df_ember['middle_east'] = df_ember.apply(func, axis=1)

# Delete area rows of type region
df_ember = df_ember.drop(df_ember_elec_generation[df_ember['area_type']=='Region'].index).reset_index(drop=True)
df_ember = df_ember.drop(df_ember[df_ember['subcategory']=='Total'].index).reset_index(drop=True)
df_ember = df_ember[df_ember.variable.str.contains(' and ')==False]

# Create new columns
df_ember['group'] = df_ember.apply(lfunc, axis=1)
df_ember['source'] = 'ember'

# Filter columns
df_ember.drop(columns=['eu', 'oecd', 'g20', 'g7', 'middle_east', 'area_type', 'ember_region'], inplace=True)

# Rename columns
df_ember.rename(columns={'area' : 'country', 'country_code' : 'country_code_a3', 'category' : 'type'}, inplace=True)

df_ember.head()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8296\2468208250.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_ember = df_ember.drop(df_ember_elec_generation[df_ember['area_type']=='Region'].index).reset_index(drop=True)
#        country country_code_a3  year region_name sub-region_name      type  \
# 0  Afghanistan             AFG  2000        Asia   Southern Asia  Capacity
# 1  Afghanistan             AFG  2000        Asia   Southern Asia  Capacity
# 4  Afghanistan             AFG  2000        Asia   Southern Asia  Capacity
# 5  Afghanistan             AFG  2000        Asia   Southern Asia  Capacity
# 6  Afghanistan             AFG  2000        Asia   Southern Asia  Capacity
#
#       subcategory      variable unit  value group source
# 0  Aggregate fuel         Clean   GW   0.19   NaN  ember
# 1  Aggregate fuel        Fossil   GW   0.03   NaN  ember
# 4  Aggregate fuel    Renewables   GW   0.19   NaN  ember
# 5            Fuel         Hydro   GW   0.19   NaN  ember
# 6            Fuel  Other Fossil   GW   0.03   NaN  ember

# %% [markdown]
# ## Electricity generation & capacity

# %%
df_ember_elec_gen_cap = df_ember[(df_ember['type'].isin(['Electricity generation', 'Capacity']))&(df_ember['unit']!='%')].reset_index()
df_ember_elec_gen_cap = df_ember_elec_gen_cap.groupby(['country', 'country_code_a3', 'year', 'region_name', 'sub-region_name', 'group', 'variable', 'type', 'unit', 'source'])['value'].sum().reset_index()
df_ember_elec_gen_cap.head()
# Out:
#      country country_code_a3  year region_name  \
# 0  Argentina             ARG  2000    Americas
# 1  Argentina             ARG  2000    Americas
# 2  Argentina             ARG  2000    Americas
# 3  Argentina             ARG  2000    Americas
# 4  Argentina             ARG  2000    Americas
#
#                    sub-region_name group   variable                    type  \
# 0  Latin America and the Caribbean   g20  Bioenergy                Capacity
# 1  Latin America and the Caribbean   g20  Bioenergy  Electricity generation
# 2  Latin America and the Caribbean   g20      Clean                Capacity
# 3  Latin America and the Caribbean   g20      Clean  Electricity generation
# 4  Latin America and the Caribbean   g20       Coal                Capacity
#
#   unit source  value
# 0   GW  ember   0.07
# 1  TWh  ember   0.36
# 2   GW  ember   9.71
# 3  TWh  ember  34.88
# 4   GW  ember   0.38

# %%
df_ember_elec_gen_cap.to_csv('../../../data/_processed/ember_electricity_generation_capacity.csv', index=False)

# %% [markdown]
# ### Electricity generation & capacity visualization

# %%
df_ember_elec_gen_cap.hvplot(x='year', by=['country', 'type', 'variable', 'unit'], groupby =['country', 'type', 'variable'], widget_location='left_top')
# Out:
# Row
#     [0] WidgetBox
#         [0] Select(margin=(20, 20, 5, 20), name='country', options=['Argentina', ...], value='Argentina', width=250)
#         [1] Select(margin=(0, 20, 5, 20), name='type', options=['Capacity', '...], value='Capacity', width=250)
#         [2] Select(margin=(5, 20, 20, 20), name='variable', options=['Bioenergy', ...], value='Bioenergy', width=250)
#     [1] HoloViews(DynamicMap, height=300, sizing_mode='fixed', widget_location='left_top', width=700)

# %% [markdown]
# ## Electricity imports

# %%
df_ember_elec_imports = df_ember[(df_ember['type']=='Electricity imports')].reset_index()
df_ember_elec_imports = df_ember_elec_imports.groupby(['country','country_code_a3', 'year', 'region_name', 'sub-region_name', 'group', 'type', 'unit', 'source'])['value'].sum().reset_index()
df_ember_elec_imports.head()
# Out:
#      country country_code_a3  year region_name  \
# 0  Argentina             ARG  2000    Americas
# 1  Argentina             ARG  2001    Americas
# 2  Argentina             ARG  2002    Americas
# 3  Argentina             ARG  2003    Americas
# 4  Argentina             ARG  2004    Americas
#
#                    sub-region_name group                 type unit source  \
# 0  Latin America and the Caribbean   g20  Electricity imports  TWh  ember
# 1  Latin America and the Caribbean   g20  Electricity imports  TWh  ember
# 2  Latin America and the Caribbean   g20  Electricity imports  TWh  ember
# 3  Latin America and the Caribbean   g20  Electricity imports  TWh  ember
# 4  Latin America and the Caribbean   g20  Electricity imports  TWh  ember
#
#    value
# 0   1.22
# 1   1.76
# 2   5.84
# 3   5.03
# 4   3.47

# %%
df_ember_elec_imports.to_csv('../../../data/_processed/ember_electricity_imports.csv', index=False)

# %% [markdown]
# ### Electricity imports visualization

# %%
df_ember_elec_imports.hvplot(x='year', by=['country', 'type', 'unit'], groupby =['country'], widget_location='left_top')
# Out:
# Row
#     [0] WidgetBox
#         [0] Select(margin=(20, 20, 20, 20), name='country', options=['Argentina', ...], value='Argentina', width=250)
#     [1] HoloViews(DynamicMap, height=300, sizing_mode='fixed', widget_location='left_top', width=700)

# %% [markdown]
# ### Electricity Demand

# %%
df_ember_elec_demand = df_ember[(df_ember['type']=='Electricity demand')].reset_index()
df_ember_elec_demand = df_ember_elec_demand.groupby(['country','country_code_a3', 'year', 'region_name', 'sub-region_name', 'group', 'type', 'subcategory', 'unit', 'source'])['value'].sum().reset_index()
df_ember_elec_demand.head()
# Out:
#      country country_code_a3  year region_name  \
# 0  Argentina             ARG  2000    Americas
# 1  Argentina             ARG  2000    Americas
# 2  Argentina             ARG  2001    Americas
# 3  Argentina             ARG  2001    Americas
# 4  Argentina             ARG  2002    Americas
#
#                    sub-region_name group                type  \
# 0  Latin America and the Caribbean   g20  Electricity demand
# 1  Latin America and the Caribbean   g20  Electricity demand
# 2  Latin America and the Caribbean   g20  Electricity demand
# 3  Latin America and the Caribbean   g20  Electricity demand
# 4  Latin America and the Caribbean   g20  Electricity demand
#
#          subcategory unit source  value
# 0             Demand  TWh  ember  86.47
# 1  Demand per capita  MWh  ember   2.33
# 2             Demand  TWh  ember  88.25
# 3  Demand per capita  MWh  ember   2.36
# 4             Demand  TWh  ember  86.99

# %%
df_ember_elec_demand.to_csv('../../../data/_processed/ember_electricity_demand.csv', index=False)

# %% [markdown]
# ### Electricity demand visualization

# %%
df_ember_elec_demand.hvplot(x='year', by=['country', 'subcategory', 'unit'], groupby =['country', 'subcategory'], widget_location='left_top')
# Out:
# Row
#     [0] WidgetBox
#         [0] Select(margin=(20, 20, 5, 20), name='country', options=['Argentina', ...], value='Argentina', width=250)
#         [1] Select(margin=(5, 20, 20, 20), name='subcategory', options=['Demand', 'Demand p...], value='Demand', width=250)
#     [1] HoloViews(DynamicMap, height=300, sizing_mode='fixed', widget_location='left_top', width=700)

# %% [markdown]
# ## Power sector emissions

# %%
df_ember_power_secor_emmissions = df_ember[(df_ember['type']=='Power sector emissions')].reset_index()
df_ember_power_secor_emmissions = df_ember_power_secor_emmissions.groupby(['country','country_code_a3', 'year', 'region_name', 'sub-region_name', 'group', 'type', 'subcategory', 'unit', 'source'])['value'].sum().reset_index()
df_ember_power_secor_emmissions.head()
# Out:
#      country country_code_a3  year region_name  \
# 0  Argentina             ARG  2000    Americas
# 1  Argentina             ARG  2000    Americas
# 2  Argentina             ARG  2000    Americas
# 3  Argentina             ARG  2001    Americas
# 4  Argentina             ARG  2001    Americas
#
#                    sub-region_name group                    type  \
# 0  Latin America and the Caribbean   g20  Power sector emissions
# 1  Latin America and the Caribbean   g20  Power sector emissions
# 2  Latin America and the Caribbean   g20  Power sector emissions
# 3  Latin America and the Caribbean   g20  Power sector emissions
# 4  Latin America and the Caribbean   g20  Power sector emissions
#
#       subcategory      unit source   value
# 0  Aggregate fuel     mtCO2  ember   27.40
# 1   CO2 intensity  gCO2/kWh  ember  312.49
# 2            Fuel     mtCO2  ember   26.64
# 3  Aggregate fuel     mtCO2  ember   23.65
# 4   CO2 intensity  gCO2/kWh  ember  262.34

# %%
df_ember_power_secor_emmissions.to_csv('../../../data/em_processed/ember_power_secor_emmissions.csv', index=False)

# %% [markdown]
# ### Power sector emissions

# %%
df_ember_power_secor_emmissions.hvplot(x='year', by=['country', 'subcategory', 'unit'], groupby =['country', 'subcategory'], widget_location='left_top')
# Out:
# Row
#     [0] WidgetBox
#         [0] Select(margin=(20, 20, 5, 20), name='country', options=['Argentina', ...], value='Argentina', width=250)
#         [1] Select(margin=(5, 20, 20, 20), name='subcategory', options=['Aggregate fuel', ...], value='Aggregate fuel', width=250)
#     [1] HoloViews(DynamicMap, height=300, sizing_mode='fixed', widget_location='left_top', width=700)
