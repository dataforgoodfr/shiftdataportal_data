# %%
import pandas as pd

# %%
df_cw_pik = pd.read_csv('../../data/_processed/CW_PIK_historical_emissions_processed.csv')
df_edgar = pd.read_csv('../../data/_processed/edgar_processed_ch4_n2o_co2_fgases.csv')

df_concat_edgar_pik_ghg_emissions = pd.concat([df_cw_pik, df_edgar],ignore_index=True)
display(df_concat_edgar_pik_ghg_emissions)

df_concat_edgar_pik_ghg_emissions.to_csv('../../data/_processed/concat_edgar_pik_ghg_emissions.csv', index=False)
# Out:
#         country_code_a3 country_name region_name       sector  gas  year  \
# 0                   ABW        Aruba   Amériques  Agriculture  CH4  1850
# 1                   ABW        Aruba   Amériques  Agriculture  N2O  1850
# 2                   ABW        Aruba   Amériques       Energy  CH4  1850
# 3                   ABW        Aruba   Amériques       Energy  CO2  1850
# 4                   ABW        Aruba   Amériques       Energy  N2O  1850
# ...                 ...          ...         ...          ...  ...   ...
# 1245607             ZWE     Zimbabwe     Afrique  Agriculture  N2O  2021
# 1245608             ZWE     Zimbabwe     Afrique  Agriculture  N2O  2021
# 1245609             ZWE     Zimbabwe     Afrique  Agriculture  N2O  2021
# 1245610             ZWE     Zimbabwe     Afrique        Waste  N2O  2021
# 1245611             ZWE     Zimbabwe     Afrique        Other  N2O  2021
#
#          value_mteqco2 source   value_kt
# 0             0.000050    PIK        NaN
# ...
