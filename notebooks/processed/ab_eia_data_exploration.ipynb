# %%
import pandas as pd

# %%
path = "../../data/_raw/eia/eia_api_intl_2020_2021.csv"
df_eia = pd.read_csv(path)



#add the name of the source
df_eia["data_source"] = "eia"

#column selection
df_eia = df_eia[["data_source", "period", "productName", "activityName", "countryRegionId", "countryRegionName", "unitName", "value", "unit"]]

#delete duplicates. Duplicates have been found on different idProduct for identical rows.
# on all columns except value because there is 1 duplicate for USA, 2020, Coal Prod with values that are almost exactly the same
df_eia = df_eia.drop_duplicates(["data_source", "period", "productName", "activityName", "countryRegionId", "countryRegionName", "unitName", "unit"])

#colums renaming
df_eia.rename(columns={
    'period': 'year',
    'productName': 'product_name',
    'activityName': 'activity_name',
    'countryRegionId': 'country_iso3',
    'countryRegionName': 'country_name',
    'unitName': 'unit_name',
}, inplace=True)

# %%
# to find duplicates
df_eia[:].value_counts(sort=True)

# %%
# we found duplicates : rows are exactly the same except for productId

df_eia[
    (df_eia["country_iso3"]=='FJI') & 
    (df_eia["activity_name"]=='Emissions') & 
    (df_eia["product_name"]=='Petroleum and other liquids') &
    (df_eia["unit"]=='MMTCD')
    ]
# Out:
#        year  productId                 product_name  activityId activity_name  \
# 65050  2021       4006  Petroleum and other liquids           8     Emissions
# 65709  2021          5  Petroleum and other liquids           8     Emissions
#
#       country_iso3 country_name countryRegionTypeId countryRegionTypeName  \
# 65050          FJI         Fiji                   c               Country
# 65709          FJI         Fiji                   c               Country
#
#        dataFlagId dataFlagDescription                             unit_name  \
# 65050         NaN                 NaN  million metric tonnes carbon dioxide
# 65709         NaN                 NaN  million metric tonnes carbon dioxide
#
#                     value   unit data_source
# 65050  1.6547908836221423  MMTCD         eia
# 65709  1.6547908836221423  MMTCD         eia

# %%
# to find duplicates
df_eia[:].value_counts(sort=True)

# %%
#calculate number of rows for each productName
df_eia["productName"].value_counts(sort=True)

#=> NEXT STEP : subset df by productName, understand data and normalize it
# Out:
# Coal                                    5789
# Anthracite                              4722
# Metallurgical coal                      4710
# Metallurgical coke                      4631
# Dry natural gas                         4563
# Subbituminous                           4239
# Bituminous                              4161
# Lignite                                 4160
# Electricity                             3569
# Petroleum and other liquids             2337
# Refined petroleum products              1825
# Other petroleum liquids                 1782
# Jet fuel                                1577
# Distillate fuel oil                     1567
# Kerosene                                1565
# Residual fuel oil                       1434
# Motor gasoline                          1404
# Primary energy                          1305
# Tide and wave                           1250
# Liquefied Petroleum Gases               1239
# Wind                                    1222
# Non-hydroelectric renewables            1219
# Crude oil including lease condensate    1195
# Renewables                              1192
# Geothermal                              1128
# Biomass and waste                       1073
# Solar                                   1060
# Solar, tide, wave, fuel cell            1049
# Hydroelectricity                         949
# NGPL                                     786
# Natural gas                              731
# Nuclear                                  632
# Biofuels                                 620
# Biomass-based diesel                     546
# Fuel ethanol                             534
# Hydroelectric pumped storage             479
# Coal and coke                            461
# Population                               460
# Energy intensity                         460
# Gross domestic product                   460
# Nuclear, renewables, and other           449
# Crude oil, NGPL, and other liquids       436
# Fossil fuels                             430
# Total petroleum and other liquids        429
# Other liquids                            429
# Renewables and other                     416
# Refinery processing gain                 399
# Gross natural gas                        250
# Consumed natural gas                     242
# CO2 emissions                            234
# Vented and flared natural gas             20
# Reinjected natural gas                    18
# Name: productName, dtype: int64

# %%
# check of all product name that has coal in its name. We'll only keep the 'Coal' and compare with SDP later
#Coal                  5789
#Metallurgical coal    4710
#Coal and coke          461
#df_eia[df_eia["productName"].str.contains('coal', case = False)]["productName"].value_counts(sort=True)

#creation of the df for the Coal
df_eia_coal = df_eia[df_eia["product_name"]=='Coal']

# %%
#calculate number of rows for each productName
df_eia_coal["activityName"].value_counts(sort=True)
# Out:
# Production     1719
# Consumption    1419
# Exports        1296
# Imports        1127
# Reserves        228
# Name: activityName, dtype: int64

# %%
#add source name


#select columns
df_eia_coal = df_eia_coal[["", ""]]

df_eia_coal.head()
# Out:
#     period  productId productName  activityId activityName countryRegionId  \
# 1     2021          7        Coal           1   Production             ZAF
# 9     2021          7        Coal           1   Production             ZAF
# 12    2021          7        Coal           1   Production             DEU
# 27    2021          7        Coal           1   Production             DEU
# 35    2021          7        Coal           1   Production             DEU
#
#    countryRegionName countryRegionTypeId countryRegionTypeName  dataFlagId  \
# 1       South Africa                   c               Country         NaN
# 9       South Africa                   c               Country         NaN
# 12           Germany                   c               Country         NaN
# 27           Germany                   c               Country         NaN
# 35           Germany                   c               Country         NaN
#
#    dataFlagDescription                               unitName  \
# 1                  NaN                             terajoules
# 9                  NaN  million metric tons of oil equivalent
# 12                 NaN                             terajoules
# 27                 NaN                    thousand short tons
# 35                 NaN  million metric tons of oil equivalent
#
#                  value  unit
# 1    5254411.855803305    TJ
# 9   125.49947103961276  MTOE
# 12  1196512.3729902192    TJ
# 27     139173.90502983   TST
# 35   28.57820704267334  MTOE

# %%
#found new duplicates
df_eia_coal.groupby(["country_iso3", "year", "activity_name"])["data_source"].count().sort_values(ascending=True)
# Out:
# country_iso3  year  activity_name
# ABW           2020  Reserves         1
# MEX           2020  Reserves         1
#               2021  Reserves         1
# MKD           2020  Reserves         1
#               2021  Reserves         1
#                                     ..
# DNK           2021  Imports          5
# MMR           2021  Production       5
#                     Exports          5
# DMA           2021  Production       5
# KWT           2020  Imports          5
# Name: data_source, Length: 885, dtype: int64

# %%
#specific row
df_eia_coal[
    (df_eia_coal["country_iso3"]=="ABW") &
    (df_eia_coal["year"]==2020) &
    (df_eia_coal["activity_name"]=="Reserves")
]
# Out:
#        data_source  year product_name activity_name country_iso3 country_name  \
# 117872         eia  2020         Coal      Reserves          ABW        Aruba
#
#                  unit_name value unit
# 117872  million short tons     0  MST

# %%
#specific row that had a duplicate
df_eia_coal[
    (df_eia_coal["country_iso3"]=="USA") &
    (df_eia_coal["year"]==2020) &
    (df_eia_coal["activity_name"]=="Consumption") &
    (df_eia_coal["unit"]=="QBTU")
]

# %%
#analysing use of unit
df_eia_coal.groupby(["unit", "unit_name"])["data_source"].count().sort_values(ascending=False)
#all units frequency use is same order of magnitude
# Out:
# unit  unit_name
# MST   million short tons                       457
# QBTU  quadrillion Btu                          426
# MT    1000 metric tons                         392
# MTOE  million metric tons of oil equivalent    390
# TST   thousand short tons                      390
# TJ    terajoules                               389
# Name: data_source, dtype: int64

# %%
#clean value column
values_to_replace = ["--", "ie"]
df_eia_coal["value"] = df_eia_coal["value"].replace(values_to_replace, 0)
# Out:
# /var/folders/pd/8mtfl9m11sbf2r8nhg8s0jc80000gp/T/ipykernel_7062/1605264477.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_eia_coal["value"] = df_eia_coal["value"].replace(values_to_replace, 0)

# %%
#somme pour calculer le ratio par unite d'energy
#df_eia_coal.groupby(["unit", "unit_name"])["value"].sum()
#df_eia_coal.info()
df_eia_coal["value"].astype(float)
#df_eia_coal[df_eia_coal["value"]=='ie']
# Out:
# 2             42.699999
# 11             0.000000
# 14             0.000000
# 94        100369.212636
# 95             0.000000
#               ...
# 118952         2.204620
# 118953      2777.821200
# 118957         0.000000
# 118958      3206.619790
# 118963         0.000000
# Name: value, Length: 2444, dtype: float64

# %%
df_eia_coal[df_eia_coal["activity_name"] != "Reserves"]
# Out:
#        data_source  year product_name activity_name country_iso3  \
# 2              eia  2020         Coal    Production          POL
# 11             eia  2021         Coal    Production          MNP
# 14             eia  2021         Coal    Production          KIR
# 94             eia  2020         Coal    Production          POL
# 95             eia  2020         Coal    Production          MDA
# ...            ...   ...          ...           ...          ...
# 102057         eia  2020         Coal       Exports          HKG
# 102062         eia  2020         Coal       Exports          HKG
# 102079         eia  2020         Coal       Exports          HKG
# 102089         eia  2020         Coal       Exports          HKG
# 102091         eia  2020         Coal       Exports          HKG
#
#                     country_name                              unit_name  \
# 2                         Poland  million metric tons of oil equivalent
# 11      Northern Mariana Islands                       1000 metric tons
# 14                      Kiribati                       1000 metric tons
# 94                        Poland                       1000 metric tons
# 95                       Moldova                             terajoules
# ...                          ...                                    ...
# 102057                 Hong Kong                    thousand short tons
# 102062                 Hong Kong                       1000 metric tons
# 102079                 Hong Kong  million metric tons of oil equivalent
# 102089                 Hong Kong                             terajoules
# 102091                 Hong Kong                        quadrillion Btu
#
#                      value  unit
# 2        42.69999895485965  MTOE
# 11                       0    MT
# 14                       0    MT
# 94      100369.21263571049    MT
# 95                       0    TJ
# ...                    ...   ...
# 102057                   0   TST
# 102062                   0    MT
# 102079                   0  MTOE
# 102089                   0    TJ
# 102091                   0  QBTU
#
# [1987 rows x 9 columns]

# %%
df_eia_coal[df_eia_coal["unit"]=="MST"].head(20)
# Out:
#        data_source  year product_name activity_name country_iso3  \
# 117609         eia  2020         Coal      Reserves          CHE
# 117615         eia  2021         Coal      Reserves          CRI
# 117616         eia  2021         Coal      Reserves          BGR
# 117617         eia  2020         Coal      Reserves          NLD
# 117630         eia  2021         Coal      Reserves          DZA
# 117631         eia  2021         Coal      Reserves          MEX
# 117634         eia  2021         Coal      Reserves          GMB
# 117635         eia  2021         Coal      Reserves          NPL
# 117656         eia  2021         Coal      Reserves          MWI
# 117657         eia  2021         Coal      Reserves          ISL
# 117658         eia  2020         Coal      Reserves          DOM
# 117659         eia  2021         Coal      Reserves          MNG
# 117660         eia  2020         Coal      Reserves          MTQ
# 117661         eia  2020         Coal      Reserves          PNG
# 117662         eia  2021         Coal      Reserves          HRV
# 117663         eia  2021         Coal      Reserves          HUN
# 117667         eia  2020         Coal      Reserves          IRN
# 117668         eia  2021         Coal      Reserves          SSD
# 117683         eia  2020         Coal      Reserves          GRC
# 117684         eia  2021         Coal      Reserves          CHE
#
#               country_name           unit_name       value unit
# 117609         Switzerland  million short tons           0  MST
# 117615          Costa Rica  million short tons           0  MST
# 117616            Bulgaria  million short tons  2608.06546  MST
# 117617         Netherlands  million short tons   547.84807  MST
# 117630             Algeria  million short tons    65.03629  MST
# 117631              Mexico  million short tons  1334.89741  MST
# 117634         Gambia, The  million short tons           0  MST
# 117635               Nepal  million short tons     1.10231  MST
# 117656              Malawi  million short tons     2.20462  MST
# 117657             Iceland  million short tons           0  MST
# 117658  Dominican Republic  million short tons           0  MST
# 117659            Mongolia  million short tons   2777.8212  MST
# 117660          Martinique  million short tons          ie  MST
# 117661    Papua New Guinea  million short tons           0  MST
# 117662             Croatia  million short tons           0  MST
# 117663             Hungary  million short tons  3206.61979  MST
# 117667                Iran  million short tons  1326.07893  MST
# 117668         South Sudan  million short tons           0  MST
# 117683              Greece  million short tons  3170.24356  MST
# 117684         Switzerland  million short tons           0  MST

# %%
#df_eia_coal[df_eia_coal["unit" != ""]].sort_values(["country_iso3", "activity_name", "year", "unit"]).head(50)

#il semble que l'unité MST soit utilisée que pour l'activité "Reserve"
df_eia_coal[df_eia_coal["activity_name"] == "Reserves"].sort_values(["country_iso3", "activity_name", "year", "unit"]).head(50)


#les unités
# Out:
#        data_source  year product_name activity_name country_iso3  \
# 117872         eia  2020         Coal      Reserves          ABW
# 117937         eia  2021         Coal      Reserves          ABW
# 118519         eia  2020         Coal      Reserves          AFG
# 118597         eia  2021         Coal      Reserves          AFG
# 118647         eia  2020         Coal      Reserves          AGO
# 118711         eia  2021         Coal      Reserves          AGO
# 117938         eia  2020         Coal      Reserves          ALB
# 118016         eia  2021         Coal      Reserves          ALB
# 118522         eia  2020         Coal      Reserves          ARE
# 118596         eia  2021         Coal      Reserves          ARE
# 118539         eia  2020         Coal      Reserves          ARG
# 118610         eia  2021         Coal      Reserves          ARG
# 118540         eia  2020         Coal      Reserves          ARM
# 118609         eia  2021         Coal      Reserves          ARM
# 118600         eia  2020         Coal      Reserves          ASM
# 118672         eia  2021         Coal      Reserves          ASM
# 117827         eia  2020         Coal      Reserves          ATA
# 117886         eia  2021         Coal      Reserves          ATA
# 118683         eia  2020         Coal      Reserves          ATG
# 118756         eia  2021         Coal      Reserves          ATG
# 118102         eia  2020         Coal      Reserves          AUS
# 118178         eia  2021         Coal      Reserves          AUS
# 118416         eia  2020         Coal      Reserves          AUT
# 118510         eia  2021         Coal      Reserves          AUT
# 117723         eia  2020         Coal      Reserves          AZE
# 117792         eia  2021         Coal      Reserves          AZE
# 117960         eia  2020         Coal      Reserves          BDI
# 118039         eia  2021         Coal      Reserves          BDI
# 118152         eia  2020         Coal      Reserves          BEL
# 118248         eia  2021         Coal      Reserves          BEL
# 117855         eia  2020         Coal      Reserves          BEN
# 117919         eia  2021         Coal      Reserves          BEN
# 118826         eia  2020         Coal      Reserves          BFA
